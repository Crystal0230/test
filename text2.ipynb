# %%
import numpy as np
c = [[1,2],[3,4]]
d = np.array(c)
display(d)
display(d.shape)
# Out:
# array([[1, 2],
#        [3, 4]])
# (2, 2)

# %%
import numpy as np
c = [[1,2],[3,4]]
d = np.array(c)
display(d)
display(d.shape)
# Out:
# array([[1, 2],
#        [3, 4]])
# (2, 2)

# %%
a = [1,1.0,'s']
b = np.array(a)
display(b)
# Out:
# array(['1', '1.0', 's'], dtype='<U32')

# %%
display(b.ndim)
display(d.ndim)
# Out:
# 1
# 2

# %%
display(b.ndim)
display(d.ndim)
# Out:
# 1
# 2

# %%
a = [1,1.0,'s']
b = np.array(a)
display(b)
# Out:
# array(['1', '1.0', 's'], dtype='<U32')

# %%
display(b.ndim)
display(d.ndim)
# Out:
# 1
# 2

# %%
display(b.shape)
display(d.shape)
# Out:
# (3,)
# (2, 2)

# %%
display(b.size)
display(d.size)
# Out:
# 3
# 4

# %%
joker = [1,2,3,4]
huwang = [1,1,1.2,1.3]
joker_array = np.array(joker)
huwang_array = np.array(huwang)
display(joker_array.dtype,huwang_array.dtype)
# Out:
# dtype('int32')
# dtype('float64')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
moun = plt.imread('C:\\Users\\dell\\Desktop\\1042029164.jpg')
display(moun)
# Out:
# array([[[84, 85, 87],
#         [84, 85, 87],
#         [84, 85, 87],
#         ...,
#         [56, 60, 61],
#         [56, 60, 61],
#         [55, 59, 60]],
#
#        [[84, 85, 87],
#         [84, 85, 87],
#         [84, 85, 87],
#         ...,
#         [56, 60, 61],
#         [55, 59, 60],
#         [54, 58, 59]],
#
#        [[85, 86, 88],
#         [85, 86, 88],
#         [85, 86, 88],
#         ...,
#         [55, 59, 60],
#         [54, 58, 59],
#         [54, 58, 59]],
#
#        ...,
#
#        [[ 9, 12, 17],
#         [ 9, 12, 17],
#         [ 9, 13, 16],
#         ...,
#         [59, 68, 85],
#         [59, 68, 85],
#         [59, 68, 85]],
#
#        [[ 8, 11, 16],
#         [ 8, 11, 16],
#         [ 9, 13, 16],
#         ...,
#         [59, 68, 85],
#         [59, 68, 85],
#         [59, 68, 85]],
#
#        [[ 8, 11, 16],
#         [ 8, 11, 16],
#         [ 9, 13, 16],
#         ...,
#         [58, 67, 84],
#         [58, 67, 84],
#         [58, 67, 84]]], dtype=uint8)

# %%
plt.imshow(moun)

# %%
moun_change = moun.copy()

# %%
moun_change.shape
# Out:
# (1080, 1620, 3)

# %%
for i in range(1080):
    for j in range(1620):
        for k in range(3):
            if moun_change[i][j][k] == 84:
                moun_change[i][j][k] =0
            if moun_change[i][j][k] == 68:
                moun_change[i][j][k] =12
            if moun_change[i][j][k] == 32:
                moun_change[i][j][k] =18

# %%
moun_change
# Out:
# array([[[ 0, 85, 87],
#         [ 0, 85, 87],
#         [ 0, 85, 87],
#         ...,
#         [56, 60, 61],
#         [56, 60, 61],
#         [55, 59, 60]],
#
#        [[ 0, 85, 87],
#         [ 0, 85, 87],
#         [ 0, 85, 87],
#         ...,
#         [56, 60, 61],
#         [55, 59, 60],
#         [54, 58, 59]],
#
#        [[85, 86, 88],
#         [85, 86, 88],
#         [85, 86, 88],
#         ...,
#         [55, 59, 60],
#         [54, 58, 59],
#         [54, 58, 59]],
#
#        ...,
#
#        [[ 9, 12, 17],
#         [ 9, 12, 17],
#         [ 9, 13, 16],
#         ...,
#         [59, 12, 85],
#         [59, 12, 85],
#         [59, 12, 85]],
#
#        [[ 8, 11, 16],
#         [ 8, 11, 16],
#         [ 9, 13, 16],
#         ...,
#         [59, 12, 85],
#         [59, 12, 85],
#         [59, 12, 85]],
#
#        [[ 8, 11, 16],
#         [ 8, 11, 16],
#         [ 9, 13, 16],
#         ...,
#         [58, 67,  0],
#         [58, 67,  0],
#         [58, 67,  0]]], dtype=uint8)

# %%
plt.imshow(moun_change)
